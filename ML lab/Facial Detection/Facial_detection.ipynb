# %%
import sys
# !{sys.executable} -m pip install tensorflow
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from PIL import Image  # Used for image loading

# ✅ Step 1: Load and Preprocess Dataset Without OpenCV
dataset_path = "/home/ranjith/ML lab/Facial Detection/Dataset"  # Path to dataset folder

images = []
labels = []

# Load images using PIL instead of OpenCV
for person_name in os.listdir(dataset_path):
    person_folder = os.path.join(dataset_path, person_name)
   
    if os.path.isdir(person_folder):
        for img_name in os.listdir(person_folder):
            img_path = os.path.join(person_folder, img_name)
           
            try:
                img = Image.open(img_path).convert("RGB")  # Open and convert to RGB
                img = img.resize((64, 64))  # Resize image
                img = np.array(img) / 255.0  # Normalize pixel values
               
                images.append(img)
                labels.append(person_name)
            except Exception as e:
                print(f"Skipping {img_name}: {e}")

# Convert lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

# Encode labels (convert names to numeric values)
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# One-hot encoding of labels
labels_encoded = to_categorical(labels_encoded)

print(f"Dataset Loaded: {len(images)} images, {len(np.unique(labels))} classes")

# ✅ Step 2: Build ANN Model
model = Sequential([
    Flatten(input_shape=(64, 64, 3)),  # Flatten images into a vector
    Dense(128, activation='relu'),  # First hidden layer
    Dense(64, activation='relu'),  # Second hidden layer
    Dense(len(np.unique(labels)), activation='softmax')  # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# ✅ Step 3: Train the Model
model.fit(images, labels_encoded, epochs=20, validation_split=0.2)

# ✅ Step 4: Predict on New Image Without OpenCV
def recognize_person(image_path):
    """Function to predict person from an image file."""
    try:
        img = Image.open(image_path).convert("RGB")  # Open and convert image
        img = img.resize((64, 64))  # Resize
        img = np.array(img) / 255.0  # Normalize
        img = img.reshape(1, 64, 64, 3)  # Reshape for model input

        prediction = model.predict(img)
        predicted_label = np.argmax(prediction)
        person_name = label_encoder.inverse_transform([predicted_label])[0]

        return person_name
    except Exception as e:
        return f"Error: {e}"

# Example usage:
test_image_path = "/home/ranjith/ML lab/Facial Detection/ashwin.jpeg"  # Replace with actual test image path
print(f"Predicted Person: {recognize_person(test_image_path)}")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/ranjith/.local/lib/python3.6/site-packages (2.6.2)
# Requirement already satisfied: gast==0.4.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: keras<2.7,>=2.6.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: clang~=5.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (5.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: numpy~=1.19.2 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: termcolor~=1.1.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: six~=1.15.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard<2.7,>=2.6.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: absl-py~=0.10 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (0.15.0)
# Requirement already satisfied: tensorflow-estimator<2.7,>=2.6.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: h5py~=3.1.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: google-pasta~=0.2 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: astunparse~=1.6.3 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorflow) (1.48.2)
# Requirement already satisfied: cached-property in /home/ranjith/.local/lib/python3.6/site-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (3.3.7)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.0.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (59.6.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/ranjith/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ranjith/.local/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (4.9.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ranjith/.local/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ranjith/.local/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ranjith/.local/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/ranjith/.local/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (4.8.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (1.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ranjith/.local/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2018.1.18)
# Requirement already satisfied: dataclasses in /home/ranjith/.local/lib/python3.6/site-packages (from werkzeug>=0.11.15->tensorboard<2.7,>=2.6.0->tensorflow) (0.8)
# Requirement already satisfied: zipp>=0.5 in /home/ranjith/.local/lib/python3.6/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/ranjith/.local/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ranjith/.local/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (3.2.2)
# Dataset Loaded: 4 images, 4 classes
# Epoch 1/20
# 1/1 [==============================] - 0s 303ms/step - loss: 1.6789 - accuracy: 0.3333 - val_loss: 7.9273 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7445 - accuracy: 0.3333 - val_loss: 12.9114 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 1/1 [==============================] - 0s 24ms/step - loss: 2.2262 - accuracy: 0.3333 - val_loss: 18.6746 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 1/1 [==============================] - 0s 21ms/step - loss: 5.8406 - accuracy: 0.3333 - val_loss: 17.8745 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 1/1 [==============================] - 0s 22ms/step - loss: 3.3690 - accuracy: 0.6667 - val_loss: 16.3257 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 1/1 [==============================] - 0s 25ms/step - loss: 1.1826 - accuracy: 0.6667 - val_loss: 14.6481 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1636 - accuracy: 1.0000 - val_loss: 16.7648 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7300 - accuracy: 0.6667 - val_loss: 16.5084 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5037 - accuracy: 0.6667 - val_loss: 15.1980 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 15.5509 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 16.7076 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0491 - accuracy: 1.0000 - val_loss: 17.7159 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3418 - accuracy: 0.6667 - val_loss: 17.8394 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1764 - accuracy: 1.0000 - val_loss: 17.4951 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 17.1347 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 16.8281 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 1/1 [==============================] - 0s 19ms/step - loss: 6.3875e-04 - accuracy: 1.0000 - val_loss: 16.5893 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 1/1 [==============================] - 0s 24ms/step - loss: 4.2360e-04 - accuracy: 1.0000 - val_loss: 16.4211 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 1/1 [==============================] - 0s 23ms/step - loss: 4.2759e-04 - accuracy: 1.0000 - val_loss: 16.3278 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 1/1 [==============================] - 0s 28ms/step - loss: 4.7987e-04 - accuracy: 1.0000 - val_loss: 16.3130 - val_accuracy: 0.0000e+00
# Predicted Person: ashwin

# %%
# Install or upgrade pgmpy
import sys
# !{sys.executable} -m pip install pgmpy --upgrade

import pandas as pd
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.inference import VariableElimination
from sklearn.preprocessing import KBinsDiscretizer

# Load the dataset
df = pd.read_csv('heart.csv')

# Discretize continuous columns using KBinsDiscretizer
discretizer = KBinsDiscretizer(n_bins=3, encode='ordinal', strategy='uniform')
continuous_cols = ['age', 'trestbps', 'chol', 'thalach']

df[continuous_cols] = discretizer.fit_transform(df[continuous_cols]).astype(int)

# Define the Bayesian Network structure
model = DiscreteBayesianNetwork([
    ('age', 'chol'),
    ('age', 'trestbps'),
    ('sex', 'cp'),
    ('cp', 'target'),
    ('chol', 'target'),
    ('fbs', 'target'),
    ('restecg', 'target'),
    ('thalach', 'target'),
    ('exang', 'target'),
])

# Fit the model
model.fit(df, estimator=MaximumLikelihoodEstimator)

# Perform inference
infer = VariableElimination(model)

# Discretize evidence values (manually mapped to bin ranges used in training)
# For example: age 58 falls in bin 1 of [37–63] divided into 3 bins.
evidence = {
    'age': 1,         # Highest age bin
    'sex': 1,         # Male
    'cp': 2,          # Asymptomatic
    'chol': 1,        # High cholesterol
    'fbs': 1,         # Fasting blood sugar > 120
    'restecg': 1,     # Abnormal ECG
    'thalach': 1,     # Moderate heart rate
    'exang': 1        # Exercise-induced angina
}
# evidence = {
#     'age': 1,         # Mid age group
#     'sex': 1,
#     'cp': 2,
#     'chol': 1,        # Mid cholesterol
#     'fbs': 0,
#     'restecg': 1,
#     'thalach': 1,
#     'exang': 0
# }

# Query
q = infer.query(variables=['target'], evidence=evidence)

# Output
print("Prediction for Heart Disease (target):")
print(q)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pgmpy in /home/ranjith/.local/lib/python3.6/site-packages (1.0.0)
# Requirement already satisfied: torch in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (1.10.2)
# Requirement already satisfied: tqdm in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (4.64.1)
# Requirement already satisfied: opt-einsum in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (3.3.0)
# Requirement already satisfied: networkx in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (2.5.1)
# Requirement already satisfied: statsmodels in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (0.12.2)
# Requirement already satisfied: pandas in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (1.1.5)
# Requirement already satisfied: numpy in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (1.19.5)
# Requirement already satisfied: pyro-ppl in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (1.8.0)
# Requirement already satisfied: scikit-learn in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (0.24.2)
# Requirement already satisfied: joblib in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (1.1.1)
# Requirement already satisfied: scipy in /home/ranjith/.local/lib/python3.6/site-packages (from pgmpy) (1.5.4)
# Requirement already satisfied: decorator<5,>=4.3 in /home/ranjith/.local/lib/python3.6/site-packages (from networkx->pgmpy) (4.4.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/lib/python3/dist-packages (from pandas->pgmpy) (2018.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ranjith/.local/lib/python3.6/site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pyro-api>=0.1.1 in /home/ranjith/.local/lib/python3.6/site-packages (from pyro-ppl->pgmpy) (0.1.2)
# Requirement already satisfied: dataclasses in /home/ranjith/.local/lib/python3.6/site-packages (from torch->pgmpy) (0.8)
# Requirement already satisfied: typing-extensions in /home/ranjith/.local/lib/python3.6/site-packages (from torch->pgmpy) (4.1.1)
# Requirement already satisfied: importlib-resources in /home/ranjith/.local/lib/python3.6/site-packages (from tqdm->pgmpy) (5.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ranjith/.local/lib/python3.6/site-packages (from scikit-learn->pgmpy) (3.1.0)
# Requirement already satisfied: patsy>=0.5 in /home/ranjith/.local/lib/python3.6/site-packages (from statsmodels->pgmpy) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas->pgmpy) (1.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/ranjith/.local/lib/python3.6/site-packages (from importlib-resources->tqdm->pgmpy) (3.6.0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-798032afe404> in <module>()
#       4
#       5 import pandas as pd
# ----> 6 from pgmpy.models import DiscreteBayesianNetwork
#       7 from pgmpy.estimators import MaximumLikelihoodEstimator
#       8 from pgmpy.inference import VariableElimination
#
# /home/ranjith/.local/lib/python3.6/site-packages/pgmpy/models/__init__.py in <module>()
#       1 from .BayesianNetwork import BayesianNetwork
# ----> 2 from .ClusterGraph import ClusterGraph
#       3 from .DiscreteBayesianNetwork import DiscreteBayesianNetwork
#       4 from .DynamicBayesianNetwork import DynamicBayesianNetwork
#       5 from .FactorGraph import FactorGraph
#
# /home/ranjith/.local/lib/python3.6/site-packages/pgmpy/models/ClusterGraph.py in <module>()
#       5 import numpy as np
#       6
# ----> 7 from pgmpy.base import UndirectedGraph
#       8 from pgmpy.factors import FactorDict, factor_product
#       9 from pgmpy.utils import compat_fns
#
# /home/ranjith/.local/lib/python3.6/site-packages/pgmpy/base/__init__.py in <module>()
#       1 from .UndirectedGraph import UndirectedGraph
# ----> 2 from .DAG import DAG, PDAG
#       3
#       4 __all__ = ["UndirectedGraph", "DAG", "PDAG"]
#
# /home/ranjith/.local/lib/python3.6/site-packages/pgmpy/base/DAG.py in <module>()
#      13
#      14
# ---> 15 class DAG(nx.DiGraph):
#      16     """
#      17     Base class for all Directed Graphical Models.
#
# /home/ranjith/.local/lib/python3.6/site-packages/pgmpy/base/DAG.py in DAG()
#     261                 self.add_node(node=nodes[index], latent=latent[index])
#     262
# --> 263     def add_edge(self, u, v, weight: int | float = None):
#     264         """
#     265         Add an edge between u and v.
#
# TypeError: unsupported operand type(s) for |: 'type' and 'type'
